# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sksurv.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("Datasets/practice/home_pricing.csv")

# %%
df
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
df = pd.get_dummies(df)

# %%
df
# Out:
#     area   price  town_monroe township  town_robinsville  town_west windsor
# 0   2600  550000                     1                 0                  0
# 1   3000  565000                     1                 0                  0
# 2   3200  610000                     1                 0                  0
# 3   3600  680000                     1                 0                  0
# 4   4000  725000                     1                 0                  0
# 5   2600  585000                     0                 0                  1
# 6   2800  615000                     0                 0                  1
# 7   3300  650000                     0                 0                  1
# 8   3600  710000                     0                 0                  1
# 9   2600  575000                     0                 1                  0
# 10  2900  600000                     0                 1                  0
# ...

# %%
df.drop("town_west windsor", axis=1)
# Out:
#     area   price  town_monroe township  town_robinsville
# 0   2600  550000                     1                 0
# 1   3000  565000                     1                 0
# 2   3200  610000                     1                 0
# 3   3600  680000                     1                 0
# 4   4000  725000                     1                 0
# 5   2600  585000                     0                 0
# 6   2800  615000                     0                 0
# 7   3300  650000                     0                 0
# 8   3600  710000                     0                 0
# 9   2600  575000                     0                 1
# 10  2900  600000                     0                 1
# 11  3100  620000                     0                 1
# 12  3600  695000                     0                 1

# %%
df = df[["area", "town_monroe township", "town_robinsville", "price"]]

# %%
df
# Out:
#     area  town_monroe township  town_robinsville   price
# 0   2600                     1                 0  550000
# 1   3000                     1                 0  565000
# 2   3200                     1                 0  610000
# 3   3600                     1                 0  680000
# 4   4000                     1                 0  725000
# 5   2600                     0                 0  585000
# 6   2800                     0                 0  615000
# 7   3300                     0                 0  650000
# 8   3600                     0                 0  710000
# 9   2600                     0                 1  575000
# 10  2900                     0                 1  600000
# 11  3100                     0                 1  620000
# 12  3600                     0                 1  695000

# %%
X = df.iloc[:,:-1].values
X
# Out:
# array([[2600,    1,    0],
#        [3000,    1,    0],
#        [3200,    1,    0],
#        [3600,    1,    0],
#        [4000,    1,    0],
#        [2600,    0,    0],
#        [2800,    0,    0],
#        [3300,    0,    0],
#        [3600,    0,    0],
#        [2600,    0,    1],
#        [2900,    0,    1],
#        [3100,    0,    1],
#        [3600,    0,    1]], dtype=int64)

# %%
y = df.iloc[:,-1].values
y
# Out:
# array([550000, 565000, 610000, 680000, 725000, 585000, 615000, 650000,
#        710000, 575000, 600000, 620000, 695000], dtype=int64)

# %%
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([[2800, 0, 1]])
# Out:
# array([590775.63964739])

# %%
model.predict([[3400, 0, 0]])
# Out:
# array([681241.66845839])

# %%
model.score(X,y)
# Out:
# 0.9573929037221873

# %%
df2 =  pd.read_csv("Datasets/practice/home_pricing.csv")

# %%
df2
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
le = LabelEncoder()

# %%
df2.town = le.fit_transform(df2.town)

# %%
df2
# Out:
#     town  area   price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  4000  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %%
X = df.iloc[:,:-1].values

# %%
y = df.iloc[:, -1].values

# %%
ohe = OneHotEncoder()

# %%
X = ohe.fit_transform(X).toarray()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\SAMARA~1\AppData\Local\Temp/ipykernel_15980/4068275661.py in <module>
# ----> 1 X = ohe.fit_transform(X).toarray()
#
# ~\anaconda3\lib\site-packages\sksurv\preprocessing.py in fit_transform(self, X, y, **fit_params)
#     101         self._check_feature_names(X, reset=True)
#     102         self._check_n_features(X, reset=True)
# --> 103         columns_to_encode = X.select_dtypes(include=["object", "category"]).columns
#     104         x_dummy = self._encode(X, columns_to_encode)
#     105
#
# AttributeError: 'numpy.ndarray' object has no attribute 'select_dtypes'

# %%
X
# Out:
# <13x12 sparse matrix of type '<class 'numpy.float64'>'
# 	with 26 stored elements in Compressed Sparse Row format>

# %%
# !pip install scikit-survival
# Out:
# ...
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Using cached scikit_survival-0.18.0-cp39-cp39-win_amd64.whl (713 kB)
# ...
#   Using cached ecos-2.0.10-cp39-cp39-win_amd64.whl (68 kB)
# ...
#   Using cached osqp-0.6.2.post5-cp39-cp39-win_amd64.whl (278 kB)
# ...
#   Using cached qdldl-0.1.5.post2-cp39-cp39-win_amd64.whl (83 kB)
# ...
